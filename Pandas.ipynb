# %%
import pandas as pd
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table', header=0, index_col=0)
#header를 열이름으로 정하고, 나라이름을 인덱스 이름으로 정함ㄴ다.
df[1]
# Out:
#                                              Summer Olympic Games  \
# Team
# Team (IOC code)                                                 №
# Afghanistan (AFG)                                              15
# Algeria (ALG)                                                  14
# Argentina (ARG)                                                25
# Armenia (ARM)                                                   7
# ...                                                           ...
# Zimbabwe (ZIM) [ZIM]                                           14
# Independent Olympic Athletes (IOA) [IOA]                        3
# Independent Olympic Participants (IOP) [IOP]                    1
# Mixed team (ZZX) [ZZX]                                          3
# Totals                                                         32
#
#                                               Summer Olympic Games.1  \
# Team
# Team (IOC code)                                                  NaN
# Afghanistan (AFG)                                                0.0
# Algeria (ALG)                                                    5.0
# Argentina (ARG)                                                 21.0
# Armenia (ARM)                                                    2.0
# ...                                                              ...
# Zimbabwe (ZIM) [ZIM]                                             3.0
# Independent Olympic Athletes (IOA) [IOA]                         1.0
# Independent Olympic Participants (IOP) [IOP]                     0.0
# Mixed team (ZZX) [ZZX]                                          11.0
# Totals                                                        5121.0
#
#                                               Summer Olympic Games.2  \
# Team
# Team (IOC code)                                                  NaN
# Afghanistan (AFG)                                                0.0
# Algeria (ALG)                                                    4.0
# Argentina (ARG)                                                 26.0
# Armenia (ARM)                                                    8.0
# ...                                                              ...
# Zimbabwe (ZIM) [ZIM]                                             4.0
# Independent Olympic Athletes (IOA) [IOA]                         0.0
# Independent Olympic Participants (IOP) [IOP]                     1.0
# Mixed team (ZZX) [ZZX]                                           6.0
# Totals                                                        5085.0
#
#                                               Summer Olympic Games.3  \
# Team
# Team (IOC code)                                                  NaN
# Afghanistan (AFG)                                                2.0
# Algeria (ALG)                                                    8.0
# Argentina (ARG)                                                 30.0
# Armenia (ARM)                                                    8.0
# ...                                                              ...
# Zimbabwe (ZIM) [ZIM]                                             1.0
# Independent Olympic Athletes (IOA) [IOA]                         1.0
# Independent Olympic Participants (IOP) [IOP]                     2.0
# Mixed team (ZZX) [ZZX]                                           8.0
# Totals                                                        5493.0
#
#                                              Summer Olympic Games.4  \
# Team
# Team (IOC code)                                               Total
# Afghanistan (AFG)                                                 2
# Algeria (ALG)                                                    17
# Argentina (ARG)                                                  77
# Armenia (ARM)                                                    18
# ...                                                             ...
# Zimbabwe (ZIM) [ZIM]                                              8
# Independent Olympic Athletes (IOA) [IOA]                          2
# Independent Olympic Participants (IOP) [IOP]                      3
# Mixed team (ZZX) [ZZX]                                           25
# Totals                                                        15703
#
#                                              Winter Olympic Games  \
# Team
# Team (IOC code)                                                 №
# Afghanistan (AFG)                                               0
# Algeria (ALG)                                                   3
# Argentina (ARG)                                                19
# Armenia (ARM)                                                   7
# ...                                                           ...
# Zimbabwe (ZIM) [ZIM]                                            1
# Independent Olympic Athletes (IOA) [IOA]                        0
# Independent Olympic Participants (IOP) [IOP]                    0
# Mixed team (ZZX) [ZZX]                                          0
# Totals                                                         23
#
#                                               Winter Olympic Games.1  \
# Team
# Team (IOC code)                                                  NaN
# Afghanistan (AFG)                                                0.0
# Algeria (ALG)                                                    0.0
# Argentina (ARG)                                                  0.0
# Armenia (ARM)                                                    0.0
# ...                                                              ...
# Zimbabwe (ZIM) [ZIM]                                             0.0
# Independent Olympic Athletes (IOA) [IOA]                         0.0
# Independent Olympic Participants (IOP) [IOP]                     0.0
# Mixed team (ZZX) [ZZX]                                           0.0
# Totals                                                        1062.0
#
#                                               Winter Olympic Games.2  \
# Team
# Team (IOC code)                                                  NaN
# Afghanistan (AFG)                                                0.0
# Algeria (ALG)                                                    0.0
# Argentina (ARG)                                                  0.0
# Armenia (ARM)                                                    0.0
# ...                                                              ...
# Zimbabwe (ZIM) [ZIM]                                             0.0
# Independent Olympic Athletes (IOA) [IOA]                         0.0
# Independent Olympic Participants (IOP) [IOP]                     0.0
# Mixed team (ZZX) [ZZX]                                           0.0
# Totals                                                        1060.0
#
#                                               Winter Olympic Games.3  \
# Team
# Team (IOC code)                                                  NaN
# Afghanistan (AFG)                                                0.0
# Algeria (ALG)                                                    0.0
# Argentina (ARG)                                                  0.0
# Armenia (ARM)                                                    0.0
# ...                                                              ...
# Zimbabwe (ZIM) [ZIM]                                             0.0
# Independent Olympic Athletes (IOA) [IOA]                         0.0
# Independent Olympic Participants (IOP) [IOP]                     0.0
# Mixed team (ZZX) [ZZX]                                           0.0
# Totals                                                        1051.0
#
#                                              Winter Olympic Games.4  \
# Team
# Team (IOC code)                                               Total
# Afghanistan (AFG)                                                 0
# Algeria (ALG)                                                     0
# Argentina (ARG)                                                   0
# Armenia (ARM)                                                     0
# ...                                                             ...
# Zimbabwe (ZIM) [ZIM]                                              0
# Independent Olympic Athletes (IOA) [IOA]                          0
# Independent Olympic Participants (IOP) [IOP]                      0
# Mixed team (ZZX) [ZZX]                                            0
# Totals                                                         3173
#
#                                              Combined total  Combined total.1  \
# Team
# Team (IOC code)                                           №               NaN
# Afghanistan (AFG)                                        15               0.0
# Algeria (ALG)                                            17               5.0
# Argentina (ARG)                                          44              21.0
# Armenia (ARM)                                            14               2.0
# ...                                                     ...               ...
# Zimbabwe (ZIM) [ZIM]                                     15               3.0
# Independent Olympic Athletes (IOA) [IOA]                  3               1.0
# Independent Olympic Participants (IOP) [IOP]              1               0.0
# Mixed team (ZZX) [ZZX]                                    3               8.0
# Totals                                                   55            6187.0
#
#                                               Combined total.2  \
# Team
# Team (IOC code)                                            NaN
# Afghanistan (AFG)                                          0.0
# Algeria (ALG)                                              4.0
# Argentina (ARG)                                           26.0
# Armenia (ARM)                                              8.0
# ...                                                        ...
# Zimbabwe (ZIM) [ZIM]                                       4.0
# Independent Olympic Athletes (IOA) [IOA]                   0.0
# Independent Olympic Participants (IOP) [IOP]               1.0
# Mixed team (ZZX) [ZZX]                                     4.0
# Totals                                                  6145.0
#
#                                               Combined total.3  \
# Team
# Team (IOC code)                                            NaN
# Afghanistan (AFG)                                          2.0
# Algeria (ALG)                                              8.0
# Argentina (ARG)                                           30.0
# Armenia (ARM)                                              8.0
# ...                                                        ...
# Zimbabwe (ZIM) [ZIM]                                       1.0
# Independent Olympic Athletes (IOA) [IOA]                   1.0
# Independent Olympic Participants (IOP) [IOP]               2.0
# Mixed team (ZZX) [ZZX]                                     4.0
# Totals                                                  6544.0
#
#                                              Combined total.4
# Team
# Team (IOC code)                                         Total
# Afghanistan (AFG)                                           2
# Algeria (ALG)                                              17
# Argentina (ARG)                                            77
# Armenia (ARM)                                              18
# ...                                                       ...
# Zimbabwe (ZIM) [ZIM]                                        8
# Independent Olympic Athletes (IOA) [IOA]                    2
# Independent Olympic Participants (IOP) [IOP]                3
# Mixed team (ZZX) [ZZX]                                     16
# Totals                                                  18876
#
# [158 rows x 15 columns]

# %%
import pandas as pd
#맨위 헤더를 열이름으로 정하고, 나라 이름을 인덱스 이름으로 정했다.
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table', header=0, index_col=0)
#모든행에 대해, 앞에서 5개ㅢ 열을 슬라이싱 하는것
summer = df[1].iloc[:,:5]
summer.columns = ['경기수','금','은','동','계']
print(summer.sort_values('금',ascending=False))
#summer.to_excel('하계올림픽.xlsx')
# Out:
#                                          경기수       금       은       동      계
# Team
# Totals                                    32  5121.0  5085.0  5493.0  15703
# United States (USA) [P] [Q] [R] [Z] [F]   28  1075.0   846.0   752.0   2673
# Soviet Union (URS) [URS]                   9   395.0   319.0   296.0   1010
# Great Britain (GBR) [GBR] [Z]             29   285.0   316.0   315.0    916
# China (CHN) [CHN]                         11   262.0   199.0   173.0    634
# ...                                       ..     ...     ...     ...    ...
# Olympic Athletes from Russia (OAR) [OAR]   0     0.0     0.0     0.0      0
# San Marino (SMR)                          16     0.0     1.0     2.0      3
# Saudi Arabia (KSA)                        12     0.0     2.0     2.0      4
# Lebanon (LIB)                             18     0.0     2.0     2.0      4
# Team (IOC code)                            №     NaN     NaN     NaN  Total
#
# [158 rows x 5 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _next_line(self)
#    2885                 try:
# -> 2886                     line = self._check_comments([self.data[self.pos]])[0]
#    2887                     self.pos += 1
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# StopIteration                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _infer_columns(self)
#    2619                     while self.line_pos <= hr:
# -> 2620                         line = self._next_line()
#    2621
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _next_line(self)
#    2898                 except IndexError:
# -> 2899                     raise StopIteration
#    2900         else:
#
# StopIteration:
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-f4801c5ce788> in <module>
#       1 import pandas as pd
# ----> 2 df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table', header=2, index_col=0)
#       3 summer = df[1].iloc[:,:5]
#       4
#       5 print(summer)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1083     io = stringify_path(io)
#    1084
# -> 1085     return _parse(
#    1086         flavor=flavor,
#    1087         io=io,
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     916     for table in tables:
#     917         try:
# --> 918             ret.append(_data_to_frame(data=table, **kwargs))
#     919         except EmptyDataError:  # empty table
#     920             continue
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in _data_to_frame(**kwargs)
#     795     # fill out elements of body that are "ragged"
#     796     _expand_elements(body)
# --> 797     with TextParser(body, header=header, **kwargs) as tp:
#     798         return tp.read()
#     799
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in TextParser(*args, **kwds)
#    2227     """
#    2228     kwds["engine"] = "python"
# -> 2229     return TextFileReader(*args, **kwds)
#    2230
#    2231
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, **kwds)
#    2308                 self.num_original_columns,
#    2309                 self.unnamed_cols,
# -> 2310             ) = self._infer_columns()
#    2311         except (TypeError, ValueError):
#    2312             self.close()
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _infer_columns(self)
#    2622                 except StopIteration as err:
#    2623                     if self.line_pos < hr:
# -> 2624                         raise ValueError(
#    2625                             f"Passed header={hr} but only {self.line_pos + 1} lines in "
#    2626                             "file"
#
# ValueError: Passed header=2 but only 2 lines in file
